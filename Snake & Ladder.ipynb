# %%
 import random 
p1=0
p2=0
def snake_and_ladders(position):
    dice=random.randint(1,6)
    rediece=position-dice
    print("dice={}".format(dice))
    position=position+dice
    print("position increament=",position)
    if position==37:
        print("the snake bite yow will again restart from position 27")
        return 27
    elif position==35:
        print("its a snake bike you will go back to 15 ")
        return 15
        
    elif position==55:
        print("the sanke bite you you will return to postion 30")
        return 30
    elif position==78:
        print("the snake bite you will return to 56")
        return 56
    elif position==96:
        print("the snake bite you will return to 87")
        return 87
    elif position==94:
        print("the snake bite you will return to 61")
        return 61
    elif dice==6 and position<100:
        print("You dice face is {} so you have another chance".format(dice))
        input("press the  "+" to get second chance")
        dice_2=random.randint(1,6)
        print("dice face {}".format(dice_2))
        return position+dice_2
        print("Present position:{}".format(position))
    elif position==50:
        print("yup","/n","you hit a ladder you will jump to position to 75")
        return 75
    elif position==42:
        print("yup","/n","you hit a ladder you will jump to position to 67")
        return 67
    elif position>100:
        print("the value is out of the range......")
        print("increment_position-dice_value=",position-dice)
        return position-dice
    elif position==28:
            print("yup","/n","you hit a ladder you will jump to position to 84")
            return 84
    elif position==16:
            print("yup","/n","you hit a ladder you will jump to position to 84")
            return 49
    else:
        return position 
while True:
    player1=input("player 1 is please enter your GOOd name=")
    p1=snake_and_ladders(p1)
    if p1==100:
        print("the player one is winner")
        break
    player2=input("player2 whats ur name lets start ur dices=")
    p2=snake_and_ladders(p2)
    if p2==100:
        print("the winner is is player2")
        break
# Out:
# player 1 is please enter your GOOd name=tony
# dice=1
# position increament= 1
# player2 whats ur name lets start ur dices=iron
# dice=3
# position increament= 3
# player 1 is please enter your GOOd name=tony
# dice=5
# position increament= 6
# player2 whats ur name lets start ur dices=iron
# dice=3
# position increament= 6
# player 1 is please enter your GOOd name=tony
# dice=4
# position increament= 10
# player2 whats ur name lets start ur dices=iron
# dice=6
# position increament= 12
# You dice face is 6 so you have another chance
# press the   to get second chance+
# dice face 2
# player 1 is please enter your GOOd name=tony
# dice=5
# position increament= 15
# player2 whats ur name lets start ur dices=iron
# dice=2
# position increament= 16
# yup /n you hit a ladder you will jump to position to 84
# player 1 is please enter your GOOd name=tony
# dice=4
# position increament= 19
# player2 whats ur name lets start ur dices=iron
# dice=5
# position increament= 54
# ...
